# %% [markdown]
# # Kaggleで作ったデータを処理

# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option("display.max_rows", 200)

# %%
train_df = pd.read_csv('train_df.csv')
test_df = pd.read_csv('test_df.csv')

# %%
train_df = train_df.drop(['Unnamed: 0'], axis=1)
test_df = test_df.drop(['Unnamed: 0'], axis=1)

# %%
train_df
# Out:
#      Survived  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class
# 0           0       3    0    1     0         0      1        0          3
# 1           1       1    1    2     3         1      3        0          2
# 2           1       3    1    1     1         0      2        1          3
# 3           1       1    1    2     3         0      3        0          2
# 4           0       3    0    2     1         0      1        1          6
# ..        ...     ...  ...  ...   ...       ...    ...      ...        ...
# 886         0       2    0    1     1         0      5        1          2
# 887         1       1    1    1     2         0      2        1          1
# 888         0       3    1    1     2         0      2        0          3
# 889         1       1    0    1     2         1      1        1          1
# 890         0       3    0    1     0         2      1        1          3
#
# [891 rows x 9 columns]

# %%
test_df
# Out:
#      Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class
# 0         3    0    2     0         2      1        1          6
# 1         3    1    2     0         0      3        0          6
# 2         2    0    3     1         2      1        1          6
# 3         3    0    1     1         0      1        1          3
# 4         3    1    1     1         0      3        0          3
# ..      ...  ...  ...   ...       ...    ...      ...        ...
# 413       3    0    1     1         0      1        1          3
# 414       1    1    2     3         1      5        1          2
# 415       3    0    2     0         0      1        1          6
# 416       3    0    1     1         0      1        1          3
# 417       3    0    1     2         1      4        0          3
#
# [418 rows x 8 columns]

# %% [markdown]
# # 変数の解説：年齢　（アプリにするので適宜変更）
#     １５歳未満を「０」、１６歳以上３２歳未満を「１」、３２歳以上４８歳未満を「２」、４８歳以上６４歳未満を「３」、６４歳以上であれば年齢を表示
#     dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0
#     dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'Age'] = 1
#     dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'Age'] = 2
#     dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'Age'] = 3
#     dataset.loc[ dataset['Age'] > 64, 'Age']

# %%
train_df.head(200)
# Out:
#      Survived  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class
# 0           0       3    0    1     0         0      1        0          3
# 1           1       1    1    2     3         1      3        0          2
# 2           1       3    1    1     1         0      2        1          3
# 3           1       1    1    2     3         0      3        0          2
# 4           0       3    0    2     1         0      1        1          6
# 5           0       3    0    1     1         2      1        1          3
# 6           0       1    0    3     3         0      1        1          3
# 7           0       3    0    0     2         0      4        0          0
# 8           1       3    1    1     1         0      3        0          3
# 9           1       2    1    0     2         1      3        0          0
# 10          1       3    1    0     2         0      2        0          0
# 11          1       1    1    3     2         0      2        1          3
# 12          0       3    0    1     1         0      1        1          3
# 13          0       3    0    2     3         0      1        0          6
# 14          0       3    1    0     0         0      2        1          0
# 15          1       2    1    3     2         0      3        1          6
# 16          0       3    0    0     2         2      4        0          0
# 17          1       2    0    1     1         0      1        1          2
# 18          0       3    1    1     2         0      3        0          3
# 19          1       3    1    1     0         1      3        1          3
# 20          0       2    0    2     2         0      1        1          4
# 21          1       2    0    2     1         0      1        1          4
# 22          1       3    1    0     1         2      2        1          0
# 23          1       1    0    1     3         0      1        1          1
# 24          0       3    1    0     2         0      2        0          0
# 25          1       3    1    2     3         0      3        0          6
# 26          0       3    0    1     0         1      1        1          3
# 27          0       1    0    1     3         0      1        0          1
# 28          1       3    1    1     0         2      2        1          3
# 29          0       3    0    1     0         0      1        1          3
# 169         0       3    0    1     3         0      1        1          3
# 170         0       1    0    3     3         0      1        1          3
# 171         0       3    0    0     2         2      4        0          0
# 172         1       3    1    0     1         0      2        0          0
# 173         0       3    0    1     1         0      1        1          3
# 174         0       1    0    3     2         1      1        1          3
# 175         0       3    0    1     0         0      1        0          3
# 176         0       3    0    1     2         0      4        0          3
# 177         0       1    1    3     2         1      2        1          3
# 178         0       2    0    1     1         0      1        1          2
# 179         0       3    0    2     0         0      1        1          6
# 180         0       3    1    1     3         0      2        0          3
# 181         0       2    0    1     2         1      1        1          2
# 182         0       3    0    0     3         0      4        0          0
# 183         1       2    0    0     3         0      4        0          0
# 184         1       3    1    0     2         0      2        0          0
# 185         0       1    0    2     3         0      1        1          2
# 186         1       3    1    1     2         2      3        0          3
# 187         1       1    0    2     2         0      1        1          2
# 188         0       3    0    2     2         2      1        0          6
# 189         0       3    0    2     0         0      1        1          6
# 190         1       2    1    1     1         0      3        1          2
# 191         0       2    0    1     1         0      1        1          2
# 192         1       3    1    1     0         0      2        0          3
# 193         1       2    0    0     2         0      4        0          0
# 194         1       1    1    2     2         1      3        1          2
# 195         1       1    1    3     3         1      2        1          3
# 196         0       3    0    1     0         2      1        1          3
# 197         0       3    0    2     1         0      1        0          6
# 198         1       3    1    1     0         2      2        1          3
# 199         0       2    1    1     1         0      2        1          2

# %% [markdown]
# # 変数の解説：IsAlone
#     独身者、もしくは家族が一名の場合「１」、家族が二人以上の場合「０」
#     for dataset in combine:
#         dataset['IsAlone'] = 0
#         dataset.loc[dataset['FamilySize'] == 1, 'IsAlone'] = 1
#
#     train_df[['IsAlone', 'Survived']].groupby(['IsAlone'], as_index=False).mean()

# %% [markdown]
# # 変数の解説：Age Class
#     Ageと客室クラスの積による特徴量
#     for dataset in combine:
#     dataset['Age*Class'] = dataset.Age * dataset.Pclass
#
#     train_df.loc[:, ['Age*Class', 'Age', 'Pclass']].head(10)

# %% [markdown]
# # 変数の解説：Embarked
#     出港地S,C,Qの三種類ある。アプリにする場合は一番多いC：１にする。
#     for dataset in combine:
#     dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)
#
#     train_df.head()

# %% [markdown]
# # 変数の解説：Title
#     侯爵や伯爵などの階級
#     title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}
#     for dataset in combine:
#         dataset['Title'] = dataset['Title'].map(title_mapping)
#         dataset['Title'] = dataset['Title'].fillna(0)
#
#     train_df.head()

# %% [markdown]
# # 変数の解説：Sex
#     性別　男性は「０」、女性は「１」
#     for dataset in combine:
#     dataset['Sex'] = dataset['Sex'].map( {'female': 1, 'male': 0} ).astype(int)
#
#     train_df.head()

# %% [markdown]
# # 変数の解説：Pclass
#     客室のランク
#     1 = 上層クラス（お金持ち）
#     2 = 中級クラス（一般階級）
#     3 = 下層クラス（労働階級）

# %% [markdown]
# # 変数の解説：Fare
#     料金、安い方から順に0,1,2,3
#     for dataset in combine:
#         dataset.loc[ dataset['Fare'] <= 7.91, 'Fare'] = 0
#         dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
#         dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare']   = 2
#         dataset.loc[ dataset['Fare'] > 31, 'Fare'] = 3
#         dataset['Fare'] = dataset['Fare'].astype(int)
#
#     train_df = train_df.drop(['FareBand'], axis=1)
#     combine = [train_df, test_df]
